# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import h5py
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
import numpy as np
import time
import torch.nn.init as ini
import multiprocessing
from multiprocessing import Queue
import random
from random import shuffle
import pickle

class InputCasNet(nn.Module):
    def __init__(self):
        super(InputCasNet, self).__init__()
        self.first_upper_layer1=nn.Sequential(
            nn.Conv2d(4,64,7),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d((4,4),stride = 1)
        )
        self.first_upper_layer2=nn.Sequential(
            nn.Conv2d(64,64,3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d((2,2),stride = 1)
        )
        self.first_under_layer1=nn.Sequential(
            nn.Conv2d(4,160,13),
            nn.BatchNorm2d(160),
            nn.ReLU()
        )
        
        self.first_final_layer=nn.Conv2d(224,5,21)
        
        self.second_upper_layer1=nn.Sequential(
            nn.Conv2d(9,64,7),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d((4,4),stride = 1)
        )
        self.second_upper_layer2=nn.Sequential(
            nn.Conv2d(64,64,3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d((2,2),stride = 1)
        )
        self.second_under_layer1=self.under_layer1 = nn.Sequential(
            nn.Conv2d(9,160,13),
            nn.BatchNorm2d(160),
            nn.ReLU()
        )
        self.second_final_layer = nn.Conv2d(224,5,21)
    
    def forward(self, x1):
        upper_x=self.first_upper_layer2(self.first_upper_layer1(x1))
        under_x=self.first_under_layer1(x1)
        x=torch.cat((upper_x, under_x), 1)
        x=self.first_final_layer(x)
        x2=x1[:, :, 16:48+1, 16:48+1]*1.0
        x2=torch.cat((x, x2), 1)
        upper_x2=self.second_upper_layer2(self.second_upper_layer1(x2))
        under_x2=self.second_under_layer1(x2)
        x3=torch.cat((upper_x2, under_x2), 1)
        x3=self.second_final_layer(x3)
        return x3

cas_net=InputCasNet()
x1 = Variable(torch.randn(1,4,65,65), requires_grad = True)
y_pred = cas_net.forward(x1)
print(y_pred)
# Out:
# Variable containing:
# (0 ,0 ,.,.) =
#  -0.3937
#
# (0 ,1 ,.,.) =
#  -0.0789
#
# (0 ,2 ,.,.) =
#   0.0586
#
# (0 ,3 ,.,.) =
#   0.0451
#
# (0 ,4 ,.,.) =
#  -0.1135
# [torch.FloatTensor of size 1x5x1x1]

# %%
f = h5py.File('/home/yiqin/train.h5','r')

#get the training set for phase 1
f_in=open("/home/yiqin/training-65x65-balanced.txt", "r")
content=f_in.readlines()
data_train_phase1=[]
data_val=[]
for line in content:
    no_n_line=line[0:len(line)-1]
    item=no_n_line.split(" ")
    if item[0]!="HG/0001":
        data_train_phase1.append([item[0], item[1], item[2], item[3], item[4]])
    else:
        data_val.append([item[0], item[1], item[2], item[3], item[4]])
f_in.close()
print ("phase 1 data preparation process completed.")

#get the training set for phase 2 and the validation set
f_in=open("/home/yiqin/training-65x65-unbalanced.txt", "r")
content=f_in.readlines()
data_train_phase2=[]
for line in content:
    no_n_line=line[0:len(line)-1]
    item=no_n_line.split(" ")
    if item[0]!="HG/0001":
        data_train_phase2.append([item[0], item[1], item[2], item[3], item[4]])
    else:
        data_val.append([item[0], item[1], item[2], item[3], item[4]])
f_in.close()
print ("phase 2 data preparation process completed.")

print(len(data_train_phase1))
print(len(data_train_phase2))
print(len(data_val))
# Out:
# phase 1 data preparation process completed.
# phase 2 data preparation process completed.
# 8071683
# 21254359
# 1186058

# %%
def create_val_batch_phase1(step = 6000, key = 299):
    val_x1 = []
    val_label = []
    batch_size = len(data_val) // step
    for i in range(batch_size):
        case,x,y,z,l = data_val.pop(i * step + key - i)
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        val_x1.append(x1)
        val_label.append(l)
    val_x1 = torch.from_numpy(np.array(val_x1))
    val_label = torch.from_numpy(np.array(val_label))
    return val_x1, val_label

# %%
#create valid_set
val_len = len(data_val)

val_x1, val_y = create_val_batch_phase1()
val_y = val_y.view(-1)
val_x1=Variable(val_x1.cuda(2))
print(len(data_val))
print(len(val_y))
# Out:
# 1185861
# 197

# %%
#set hyper_param
learning_rate = 5e-6
l1_reg = 5e-5
optimizer = torch.optim.SGD(cas_net.parameters(), lr=learning_rate, momentum = 0.9, weight_decay = 5e-9)

# %%
for param in cas_net.parameters():
    if len(param.size())==4:
        ini.uniform(param, a=-5e-6, b=5e-6)

# %%
def create_batch(size, j):
    train_x1 = []
    train_label = []
    for i in range(size):
        case,x,y,z,l = data_train_phase1[j * size + i]
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        train_x1.append(x1)
        train_label.append(l)
    train_x1 = torch.from_numpy(np.array(train_x1))
    train_label = torch.from_numpy(np.array(train_label))
    return train_x1, train_label

# %%
cas_net.cuda(2)
prev_time = time.clock()
num_epoch = 10
batch_size = 128
step_size = len(data_train_phase1) // batch_size
num_times=num_epoch*step_size
print(num_times)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)
# Out:
# 630600

# %%
for i in range(num_epoch):
    random.shuffle(data_train_phase1)
    for j in range(step_size):
        training_x1, training_label = create_batch(batch_size, j)
        x1_train, y_train = Variable(training_x1.cuda(2)), Variable(training_label.cuda(2), requires_grad=False)
        y_pred = cas_net.forward(x1_train)
        y_pred = y_pred.view(-1,5)
        loss = F.cross_entropy(y_pred, y_train)#cross entropy loss

#        l1_crit = nn.L1Loss(size_average = False)#L1 loss
#        reg_loss = 0
#        for param in net.parameters():
#            reg_loss += l1_crit(param)
#        loss+= l1_reg * reg_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #check accuracy
        index=i*step_size+j
        if index % 2000 == 0:
            print ("")
            print (str(index)+' time used %.3f' % (time.clock()-prev_time))
            print ('phase 1: '+str(float(index)/num_times*100)+"% completed")
            print (loss)
            y_val_pred=cas_net.forward(val_x1)
            y_val_pred=y_val_pred.view(-1,5)
            useless, predicted=torch.max(y_val_pred.data, 1)
            correct = (predicted == val_y.cuda(2)).sum()
            print('Validation accuracy:', float(correct)/len(val_y))
    scheduler.step()
    print ("phase1 epoch: " + str(i)+" successfully trained!")
    torch.save(cas_net.state_dict(), "/home/yiqin/phase1_input_cas_net.txt")
    print ("phase1 epoch: " + str(i)+" successfully saved!")
# Out:
# 0 time used 14.088
# phase 1: 0.0% completed
# Variable containing:
#  1.6094
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.07614213197969544
#
# 10 time used 19.282
# phase 1: 0.001585791309863622% completed
# Variable containing:
#  1.6095
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.08629441624365482
#
# 20 time used 24.256
# phase 1: 0.003171582619727244% completed
# Variable containing:
#  1.6030
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.817258883248731
#
# 30 time used 29.207
# phase 1: 0.004757373929590866% completed
# Variable containing:
#  1.5456
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8375634517766497
#
# 40 time used 34.278
# phase 1: 0.006343165239454488% completed
# Variable containing:
#  1.4438
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8324873096446701
#
# 50 time used 39.280
# phase 1: 0.00792895654931811% completed
# Variable containing:
#  1.3594
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8527918781725888
#
# 60 time used 44.419
# phase 1: 0.009514747859181731% completed
# Variable containing:
#  1.3023
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8527918781725888
#
# 70 time used 49.386
# phase 1: 0.011100539169045354% completed
# Variable containing:
#  1.1811
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8426395939086294
#
# 80 time used 54.309
# phase 1: 0.012686330478908976% completed
# Variable containing:
#  1.1365
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8324873096446701
#
# 90 time used 59.809
# phase 1: 0.014272121788772598% completed
# Variable containing:
#  1.2220
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8375634517766497
#
# 100 time used 64.783
# phase 1: 0.01585791309863622% completed
# Variable containing:
#  1.1819
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8274111675126904
# phase1 epoch: 0 successfully trained!
# phase1 epoch: 0 successfully saved!
#
# 63060 time used 78.290
# phase 1: 10.0% completed
# Variable containing:
#  1.1995
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8223350253807107
#
# 63070 time used 83.274
# phase 1: 10.001585791309864% completed
# Variable containing:
#  1.1772
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.817258883248731
#
# 63080 time used 88.222
# phase 1: 10.003171582619727% completed
# Variable containing:
#  1.1281
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.817258883248731
#
# 63090 time used 93.056
# phase 1: 10.004757373929591% completed
# Variable containing:
#  1.0844
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7868020304568528
#
# 63100 time used 97.948
# phase 1: 10.006343165239455% completed
# Variable containing:
#  1.1110
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7969543147208121
#
# 63110 time used 103.108
# phase 1: 10.007928956549318% completed
# Variable containing:
#  1.0610
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7868020304568528
#
# 63120 time used 108.147
# phase 1: 10.009514747859182% completed
# Variable containing:
#  1.0560
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7715736040609137
#
# 63130 time used 113.216
# phase 1: 10.011100539169044% completed
# Variable containing:
#  0.9504
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8020304568527918
#
# 63140 time used 118.251
# phase 1: 10.012686330478909% completed
# Variable containing:
#  1.0678
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7411167512690355
#
# 63150 time used 123.296
# phase 1: 10.014272121788773% completed
# Variable containing:
#  0.9718
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 63160 time used 128.330
# phase 1: 10.015857913098635% completed
# Variable containing:
#  1.0608
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7918781725888325
# phase1 epoch: 1 successfully trained!
# phase1 epoch: 1 successfully saved!
#
# 126120 time used 142.087
# phase 1: 20.0% completed
# Variable containing:
#  0.9902
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7918781725888325
#
# 126130 time used 147.208
# phase 1: 20.001585791309864% completed
# Variable containing:
#  0.9689
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7918781725888325
#
# 126140 time used 152.078
# phase 1: 20.00317158261973% completed
# Variable containing:
#  0.9704
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7817258883248731
#
# 126150 time used 156.957
# phase 1: 20.00475737392959% completed
# Variable containing:
#  0.9519
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7614213197969543
#
# 126160 time used 161.799
# phase 1: 20.006343165239453% completed
# Variable containing:
#  0.9712
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 126170 time used 166.892
# phase 1: 20.007928956549318% completed
# Variable containing:
#  1.0490
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7614213197969543
#
# 126180 time used 172.363
# phase 1: 20.009514747859182% completed
# Variable containing:
#  0.9835
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.751269035532995
#
# 126190 time used 177.440
# phase 1: 20.011100539169046% completed
# Variable containing:
#  1.1405
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.751269035532995
#
# 126200 time used 182.524
# phase 1: 20.01268633047891% completed
# Variable containing:
#  1.0613
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 126210 time used 187.646
# phase 1: 20.014272121788775% completed
# Variable containing:
#  1.0624
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7614213197969543
#
# 126220 time used 192.706
# phase 1: 20.015857913098635% completed
# Variable containing:
#  1.0053
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
# phase1 epoch: 2 successfully trained!
# phase1 epoch: 2 successfully saved!
#
# 189180 time used 206.579
# phase 1: 30.0% completed
# Variable containing:
#  0.9685
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 189190 time used 211.481
# phase 1: 30.001585791309864% completed
# Variable containing:
#  0.9199
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 189200 time used 216.715
# phase 1: 30.003171582619725% completed
# Variable containing:
#  0.9467
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 189210 time used 221.728
# phase 1: 30.004757373929593% completed
# Variable containing:
#  1.0034
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 189220 time used 226.728
# phase 1: 30.006343165239453% completed
# Variable containing:
#  1.0176
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.766497461928934
#
# 189230 time used 231.763
# phase 1: 30.007928956549318% completed
# Variable containing:
#  1.0033
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7614213197969543
#
# 189240 time used 236.843
# phase 1: 30.009514747859185% completed
# Variable containing:
#  1.0169
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7614213197969543
#
# 189250 time used 241.913
# phase 1: 30.011100539169043% completed
# Variable containing:
#  1.0556
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 189260 time used 247.002
# phase 1: 30.01268633047891% completed
# Variable containing:
#  0.9182
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 189270 time used 252.052
# phase 1: 30.01427212178877% completed
# Variable containing:
#  1.0694
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 189280 time used 257.150
# phase 1: 30.015857913098635% completed
# Variable containing:
#  1.0139
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
# phase1 epoch: 3 successfully trained!
# phase1 epoch: 3 successfully saved!
#
# 252240 time used 271.117
# phase 1: 40.0% completed
# Variable containing:
#  0.9235
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 252250 time used 275.964
# phase 1: 40.001585791309864% completed
# Variable containing:
#  0.9681
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.7563451776649747
#
# 252260 time used 281.031
# phase 1: 40.00317158261973% completed
# Variable containing:
#  1.1548
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-81d34af6ed4e> in <module>()
#      27             y_val_pred=y_val_pred.view(-1,5)
#      28             useless, predicted=torch.max(y_val_pred.data, 1)
# ---> 29             correct = (predicted == val_y.cuda(2)).sum()
#      30             print('Validation accuracy:', float(correct)/len(val_y))
#      31     scheduler.step()
#
# /home/yiqin/anaconda3/lib/python3.6/site-packages/torch/_utils.py in _cuda(self, device, async)
#      64         else:
#      65             new_type = getattr(torch.cuda, self.__class__.__name__)
# ---> 66             return new_type(self.size()).copy_(self, async)
#      67
#      68
#
# KeyboardInterrupt:

# %%
def create_batch2(size, j):
    train_x1 = []
    train_label = []
    for i in range(size):
        case,x,y,z,l = data_train_phase2[j * size + i]
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        train_x1.append(x1)
        train_label.append(l)
    train_x1 = torch.from_numpy(np.array(train_x1))
    train_label = torch.from_numpy(np.array(train_label))
    return train_x1, train_label

# %%
cas_net=InputCasNet()
cas_net.load_state_dict(torch.load("/home/yiqin/phase1_input_cas_net.txt"))
cas_net.cuda(2)
prev_time = time.clock()
num_epoch = 4
batch_size = 128
step_size = len(data_train_phase2) // batch_size
num_times=num_epoch*step_size
print(num_times)
learning_rate = 5e-7
l1_reg = 5e-5
optimizer = torch.optim.SGD(cas_net.second_final_layer.parameters(), lr=learning_rate, momentum = 0.9, weight_decay = 5e-9)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)
# Out:
# 664196

# %%
for i in range(num_epoch):
    random.shuffle(data_train_phase2)
    for j in range(200):
        training_x1, training_label = create_batch2(batch_size, j)
        x1_train, y_train = Variable(training_x1.cuda(2)), Variable(training_label.cuda(2), requires_grad=False)
        y_pred = cas_net.forward(x1_train)
        y_pred = y_pred.view(-1,5)
        loss = F.cross_entropy(y_pred, y_train)#cross entropy loss

#        l1_crit = nn.L1Loss(size_average = False)#L1 loss
#        reg_loss = 0
#        for param in net.parameters():
#            reg_loss += l1_crit(param)
#        loss+= l1_reg * reg_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #check accuracy
        index=i*step_size+j
        if index % 20 == 0:
            print ("")
            print (str(index)+' time used %.3f' % (time.clock()-prev_time))
            print ('phase 2: '+str(float(index)/num_times*100)+"% completed")
            print (loss)
            y_val_pred=cas_net.forward(val_x1)
            y_val_pred=y_val_pred.view(-1,5)
            useless, predicted=torch.max(y_val_pred.data, 1)
            correct = (predicted == val_y.cuda(2)).sum()
            print('Validation accuracy:', float(correct)/len(val_y))
    scheduler.step()
    print ("phase2 epoch: " + str(i)+" successfully trained!")
    #torch.save(cas_net.state_dict(), "/home/yiqin/phase2_input_cas_net.txt")
    print ("phase2 epoch: " + str(i)+" successfully saved!")
# Out:
# 0 time used 132.150
# phase 2: 0.0% completed
# Variable containing:
#  1.5281
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8477157360406091
#
# 20 time used 141.337
# phase 2: 0.0030111593565754686% completed
# Variable containing:
#  2.2386
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8477157360406091
#
# 40 time used 150.498
# phase 2: 0.006022318713150937% completed
# Variable containing:
#  2.1641
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8527918781725888
#
# 60 time used 161.013
# phase 2: 0.009033478069726406% completed
# Variable containing:
#  1.3681
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8781725888324873
#
# 80 time used 170.294
# phase 2: 0.012044637426301874% completed
# Variable containing:
#  1.1946
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.8934010152284264
#
# 100 time used 179.898
# phase 2: 0.015055796782877343% completed
# Variable containing:
#  1.7887
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.9035532994923858
#
# 120 time used 189.593
# phase 2: 0.018066956139452812% completed
# Variable containing:
#  1.5827
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.9035532994923858
#
# 140 time used 199.171
# phase 2: 0.02107811549602828% completed
# Variable containing:
#  1.7593
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.9086294416243654
#
# 160 time used 208.798
# phase 2: 0.02408927485260375% completed
# Variable containing:
#  1.2990
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.9137055837563451
#
# 180 time used 218.172
# phase 2: 0.027100434209179215% completed
# Variable containing:
#  1.4929
# [torch.cuda.FloatTensor of size 1 (GPU 2)]
#
# Validation accuracy: 0.9137055837563451
# phase2 epoch: 0 successfully trained!
# phase2 epoch: 0 successfully saved!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-6640c9fecd48> in <module>()
#       1 for i in range(num_epoch):
# ----> 2     random.shuffle(data_train_phase2)
#       3     for j in range(200):
#       4         training_x1, training_label = create_batch2(batch_size, j)
#       5         x1_train, y_train = Variable(training_x1.cuda(2)), Variable(training_label.cuda(2), requires_grad=False)
#
# /home/yiqin/anaconda3/lib/python3.6/random.py in shuffle(self, x, random)
#     271             for i in reversed(range(1, len(x))):
#     272                 # pick an element in x[:i+1] with which to exchange x[i]
# --> 273                 j = randbelow(i+1)
#     274                 x[i], x[j] = x[j], x[i]
#     275         else:
#
# /home/yiqin/anaconda3/lib/python3.6/random.py in _randbelow(self, n, int, maxsize, type, Method, BuiltinMethod)
#     230         if type(random) is BuiltinMethod or type(getrandbits) is Method:
#     231             k = n.bit_length()  # don't use (n-1) here because n can be 1
# --> 232             r = getrandbits(k)          # 0 <= r < 2**k
#     233             while r >= n:
#     234                 r = getrandbits(k)
#
# KeyboardInterrupt:
