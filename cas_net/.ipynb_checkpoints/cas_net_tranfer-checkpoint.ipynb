# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import h5py
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
import numpy as np
import time
import torch.nn.init as ini
import multiprocessing
from multiprocessing import Queue
import random
from random import shuffle
import pickle

class TwoPathConv(nn.Module):
    def __init__(self):
        super(TwoPathConv, self).__init__()
        self.local_conv1 = nn.Conv2d(4, 64, 7)
        #self.bn1 = nn.BatchNorm2d(64)
        self.local_conv2 = nn.Conv2d(64, 64, 3)
        #self.bn2 = nn.BatchNorm2d(64)
        self.local_conv3 = nn.Conv2d(4, 160, 13)
        #self.bn3 = nn.BatchNorm2d(160)
        self.total_conv = nn.Conv2d(224, 5, 21)

    def forward(self, x):
        under_x = F.relu(self.local_conv3(x))
        x = self.local_conv1(x)
        #x = self.bn1(x)
        x = F.max_pool2d(F.relu(x), 4, stride = 1)
        x = self.local_conv2(x)
        #x = self.bn2(x)
        x = F.max_pool2d(F.relu(x), 2, stride = 1)
        x = torch.cat((x, under_x), 1)
        x = self.total_conv(x)
        return x

# %%
class TwoPathConv_alter(nn.Module):
    def __init__(self):
        super(TwoPathConv_alter, self).__init__()
        self.upper_layer1 = nn.Sequential(
            nn.Conv2d(9,64,7),
            nn.ReLU(),
            nn.MaxPool2d((4,4),stride = 1)
        )
        self.upper_layer2 = nn.Sequential(
            nn.Conv2d(64,64,3),
            nn.ReLU(),
            nn.MaxPool2d((2,2),stride = 1)
        )
        self.under_layer1 = nn.Sequential(
            nn.Conv2d(9,160,13),
            nn.ReLU()
        )
        self.final_layer = nn.Conv2d(224,5,21)
    def forward(self, x):
        upper_x = self.upper_layer2(self.upper_layer1(x))
        under_x = self.under_layer1(x)
        out = torch.cat((under_x, upper_x), 1)
        return out

# %%
class Cascaded(nn.Module):
    def __init__(self, net1, net2):
        super(Cascaded, self).__init__()
        self.twopathconv1 = net1
        self.twopathconv2 = net2
        self.final_layer = nn.Conv2d(224, 5, 21)
    def forward(self, x1):
        x2 = x1[:, :, 16:48+1, 16:48+1]*1.0
        upper_x = self.twopathconv1(x1)
        lower_x = torch.cat((upper_x, x2), 1)
        final_x = self.twopathconv2(lower_x)
        out = self.final_layer(final_x)
        return out

# %%
net1=TwoPathConv()
net1.load_state_dict(torch.load("/home/yiqin/two_path_cnn/p2_TPWconv_net1.txt"))
net2=TwoPathConv_alter()

# %%
for param in net2.parameters():
    if len(param.size())==4:
        ini.uniform(param, a=-5e-4, b=5e-4)

# %%
cas_net=Cascaded(net1, net2)
x1 = Variable(torch.randn(1,4,65,65), requires_grad = True)
y_pred = cas_net.forward(x1)
print(y_pred)
# Out:
# Variable containing:
# (0 ,0 ,.,.) =
# 1.00000e-02 *
#    1.8111
#
# (0 ,1 ,.,.) =
# 1.00000e-02 *
#    3.8894
#
# (0 ,2 ,.,.) =
# 1.00000e-02 *
#    0.5246
#
# (0 ,3 ,.,.) =
# 1.00000e-02 *
#    0.0692
#
# (0 ,4 ,.,.) =
# 1.00000e-02 *
#    1.7305
# [torch.FloatTensor of size 1x5x1x1]

# %%
f = h5py.File('/home/yiqin/train.h5','r')

#get the training set for phase 1
f_in=open("/home/yiqin/training-65x65-balanced.txt", "r")
content=f_in.readlines()
data_train_phase1=[]
data_val=[]
for line in content:
    no_n_line=line[0:len(line)-1]
    item=no_n_line.split(" ")
    if item[0]!="HG/0001":
        data_train_phase1.append([item[0], item[1], item[2], item[3], item[4]])
    else:
        data_val.append([item[0], item[1], item[2], item[3], item[4]])
f_in.close()
print ("phase 1 data preparation process completed.")

#get the training set for phase 2 and the validation set
f_in=open("/home/yiqin/training-65x65-unbalanced.txt", "r")
content=f_in.readlines()
data_train_phase2=[]
for line in content:
    no_n_line=line[0:len(line)-1]
    item=no_n_line.split(" ")
    if item[0]!="HG/0001":
        data_train_phase2.append([item[0], item[1], item[2], item[3], item[4]])
    else:
        data_val.append([item[0], item[1], item[2], item[3], item[4]])
f_in.close()
print ("phase 2 data preparation process completed.")

print(len(data_train_phase1))
print(len(data_train_phase2))
print(len(data_val))
# Out:
# phase 1 data preparation process completed.
# phase 2 data preparation process completed.
# 8071683
# 21254359
# 1186058

# %%
def create_val_batch_phase1(step = 6000, key = 299):
    val_x1 = []
    val_label = []
    batch_size = len(data_val) // step
    for i in range(batch_size):
        case,x,y,z,l = data_val.pop(i * step + key - i)
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        val_x1.append(x1)
        val_label.append(l)
    val_x1 = torch.from_numpy(np.array(val_x1))
    val_label = torch.from_numpy(np.array(val_label))
    return val_x1, val_label

# %%
#create valid_set
val_len = len(data_val)

val_x1, val_y = create_val_batch_phase1()
val_y = val_y.view(-1)
val_x1=Variable(val_x1.cuda(3))
print(len(data_val))
print(len(val_y))
# Out:
# 1185861
# 197

# %%
print(val_x1.size())
# Out:
# torch.Size([197, 4, 65, 65])

# %%
#set hyper_param
learning_rate = 3e-6
l1_reg = 5e-5
optimizer = torch.optim.SGD(cas_net.twopathconv2.parameters(), lr=learning_rate, momentum = 0.9, weight_decay = 5e-10)

# %%
def create_batch(size, j):
    train_x1 = []
    train_label = []
    for i in range(size):
        case,x,y,z,l = data_train_phase1[j * size + i]
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        train_x1.append(x1)
        train_label.append(l)
    train_x1 = torch.from_numpy(np.array(train_x1))
    train_label = torch.from_numpy(np.array(train_label))
    return train_x1, train_label

# %%
cas_net.cuda(3)
prev_time = time.clock()
num_epoch = 5
batch_size = 128
step_size = len(data_train_phase1) // batch_size
num_times=num_epoch*step_size
print(num_times)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)
# Out:
# 315300

# %%
for i in range(num_epoch):
    random.shuffle(data_train_phase1)
    for j in range(step_size):
        training_x1, training_label = create_batch(batch_size, j)
        x1_train, y_train = Variable(training_x1.cuda(3)), Variable(training_label.cuda(3), requires_grad=False)
        y_pred = cas_net.forward(x1_train)
        y_pred = y_pred.view(-1,5)
        loss = F.cross_entropy(y_pred, y_train)#cross entropy loss

#        l1_crit = nn.L1Loss(size_average = False)#L1 loss
#        reg_loss = 0
#        for param in net.parameters():
#            reg_loss += l1_crit(param)
#        loss+= l1_reg * reg_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #check accuracy
        index=i*step_size+j
        if index % 2000 == 0:
            print ("")
            print (str(index)+' time used %.3f' % (time.clock()-prev_time))
            print ('phase 1: '+str(float(index)/num_times*100)+"% completed")
            print (loss)
            y_val_pred=cas_net.forward(val_x1)
            y_val_pred=y_val_pred.view(-1,5)
            useless, predicted=torch.max(y_val_pred.data, 1)
            correct = (predicted == val_y.cuda(3)).sum()
            print('Validation accuracy:', float(correct)/len(val_y))
    scheduler.step()
    print ("phase1 epoch: " + str(i)+" successfully trained!")
    torch.save(cas_net.state_dict(), "/home/yiqin/phase1_transfer_cas_net.txt")
    print ("phase1 epoch: " + str(i)+" successfully saved!")
# Out:
# 0 time used 16.462
# phase 1: 0.0% completed
# Variable containing:
#  1.6092
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.2639593908629442
#
# 10 time used 22.149
# phase 1: 0.003171582619727244% completed
# Variable containing:
#  1.5857
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8426395939086294
#
# 20 time used 27.827
# phase 1: 0.006343165239454488% completed
# Variable containing:
#  1.5575
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8578680203045685
#
# 30 time used 33.385
# phase 1: 0.009514747859181731% completed
# Variable containing:
#  1.5161
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8578680203045685
#
# 40 time used 38.864
# phase 1: 0.012686330478908976% completed
# Variable containing:
#  1.4373
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8629441624365483
#
# 50 time used 44.582
# phase 1: 0.01585791309863622% completed
# Variable containing:
#  1.4315
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.868020304568528
#
# 60 time used 50.251
# phase 1: 0.019029495718363463% completed
# Variable containing:
#  1.4181
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8730964467005076
#
# 70 time used 55.907
# phase 1: 0.022201078338090707% completed
# Variable containing:
#  1.3533
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8781725888324873
#
# 80 time used 61.695
# phase 1: 0.02537266095781795% completed
# Variable containing:
#  1.3463
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.883248730964467
#
# 90 time used 67.536
# phase 1: 0.028544243577545196% completed
# Variable containing:
#  1.2965
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.883248730964467
#
# 100 time used 73.055
# phase 1: 0.03171582619727244% completed
# Variable containing:
#  1.2491
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8934010152284264
# phase1 epoch: 0 successfully trained!
# phase1 epoch: 0 successfully saved!
#
# 63060 time used 89.458
# phase 1: 20.0% completed
# Variable containing:
#  1.3123
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8934010152284264
#
# 63070 time used 95.037
# phase 1: 20.00317158261973% completed
# Variable containing:
#  1.2059
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8934010152284264
#
# 63080 time used 100.704
# phase 1: 20.006343165239453% completed
# Variable containing:
#  1.2114
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.8934010152284264
#
# 63090 time used 106.150
# phase 1: 20.009514747859182% completed
# Variable containing:
#  1.1919
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 63100 time used 111.847
# phase 1: 20.01268633047891% completed
# Variable containing:
#  1.2537
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9086294416243654
#
# 63110 time used 117.579
# phase 1: 20.015857913098635% completed
# Variable containing:
#  1.1175
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 63120 time used 123.438
# phase 1: 20.019029495718364% completed
# Variable containing:
#  1.2268
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 63130 time used 129.308
# phase 1: 20.02220107833809% completed
# Variable containing:
#  1.1456
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 63140 time used 135.030
# phase 1: 20.025372660957817% completed
# Variable containing:
#  1.0850
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 63150 time used 140.835
# phase 1: 20.028544243577546% completed
# Variable containing:
#  1.0866
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 63160 time used 146.922
# phase 1: 20.03171582619727% completed
# Variable containing:
#  1.0967
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
# phase1 epoch: 1 successfully trained!
# phase1 epoch: 1 successfully saved!
#
# 126120 time used 164.223
# phase 1: 40.0% completed
# Variable containing:
#  1.1533
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126130 time used 170.213
# phase 1: 40.00317158261973% completed
# Variable containing:
#  1.0970
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126140 time used 176.205
# phase 1: 40.00634316523946% completed
# Variable containing:
#  1.0849
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126150 time used 182.191
# phase 1: 40.00951474785918% completed
# Variable containing:
#  0.9984
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126160 time used 188.051
# phase 1: 40.01268633047891% completed
# Variable containing:
#  1.0872
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126170 time used 194.041
# phase 1: 40.015857913098635% completed
# Variable containing:
#  1.1607
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126180 time used 200.018
# phase 1: 40.019029495718364% completed
# Variable containing:
#  1.1021
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126190 time used 206.043
# phase 1: 40.02220107833809% completed
# Variable containing:
#  1.1159
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126200 time used 212.049
# phase 1: 40.02537266095782% completed
# Variable containing:
#  1.0963
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126210 time used 217.978
# phase 1: 40.02854424357755% completed
# Variable containing:
#  1.0363
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9137055837563451
#
# 126220 time used 223.903
# phase 1: 40.03171582619727% completed
# Variable containing:
#  1.0984
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
# phase1 epoch: 2 successfully trained!
# phase1 epoch: 2 successfully saved!
#
# 189180 time used 239.939
# phase 1: 60.0% completed
# Variable containing:
#  1.1443
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189190 time used 245.936
# phase 1: 60.00317158261973% completed
# Variable containing:
#  1.0590
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189200 time used 251.869
# phase 1: 60.00634316523945% completed
# Variable containing:
#  1.0841
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189210 time used 257.782
# phase 1: 60.009514747859185% completed
# Variable containing:
#  1.0459
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189220 time used 263.756
# phase 1: 60.01268633047891% completed
# Variable containing:
#  1.0008
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189230 time used 269.713
# phase 1: 60.015857913098635% completed
# Variable containing:
#  1.0902
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189240 time used 275.690
# phase 1: 60.01902949571837% completed
# Variable containing:
#  1.0775
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189250 time used 281.716
# phase 1: 60.022201078338085% completed
# Variable containing:
#  1.1154
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189260 time used 287.687
# phase 1: 60.02537266095782% completed
# Variable containing:
#  1.0794
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189270 time used 293.726
# phase 1: 60.02854424357754% completed
# Variable containing:
#  1.0885
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 189280 time used 299.556
# phase 1: 60.03171582619727% completed
# Variable containing:
#  1.0329
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
# phase1 epoch: 3 successfully trained!
# phase1 epoch: 3 successfully saved!
#
# 252240 time used 315.695
# phase 1: 80.0% completed
# Variable containing:
#  1.1153
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252250 time used 321.609
# phase 1: 80.00317158261973% completed
# Variable containing:
#  1.1053
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252260 time used 327.581
# phase 1: 80.00634316523946% completed
# Variable containing:
#  1.0405
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252270 time used 333.424
# phase 1: 80.00951474785919% completed
# Variable containing:
#  1.0227
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252280 time used 339.393
# phase 1: 80.01268633047891% completed
# Variable containing:
#  1.0871
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252290 time used 345.330
# phase 1: 80.01585791309863% completed
# Variable containing:
#  1.0504
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252300 time used 351.348
# phase 1: 80.01902949571836% completed
# Variable containing:
#  1.0808
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252310 time used 357.337
# phase 1: 80.0222010783381% completed
# Variable containing:
#  1.0879
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252320 time used 363.325
# phase 1: 80.02537266095781% completed
# Variable containing:
#  1.1142
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252330 time used 369.334
# phase 1: 80.02854424357754% completed
# Variable containing:
#  1.1034
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 252340 time used 375.374
# phase 1: 80.03171582619727% completed
# Variable containing:
#  1.1302
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
# phase1 epoch: 4 successfully trained!
# phase1 epoch: 4 successfully saved!

# %%
def create_batch2(size, j):
    train_x1 = []
    train_label = []
    for i in range(size):
        case,x,y,z,l = data_train_phase2[j * size + i]
        x,y,z,l = int(x), int(y), int(z), int(l)
        case1 = case[0:2]
        case2 = case[3:]
        x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
        train_x1.append(x1)
        train_label.append(l)
    train_x1 = torch.from_numpy(np.array(train_x1))
    train_label = torch.from_numpy(np.array(train_label))
    return train_x1, train_label

# %%
net1=TwoPathConv()
net2=TwoPathConv_alter()
cas_net=Cascaded(net1, net2)
cas_net.load_state_dict(torch.load("/home/yiqin/phase1_transfer_cas_net.txt"))
cas_net.cuda(3)
prev_time = time.clock()
num_epoch = 2
batch_size = 128
step_size = len(data_train_phase2) // batch_size
num_times=num_epoch*step_size
print(num_times)
learning_rate = 2e-7
l1_reg = 5e-5
optimizer = torch.optim.SGD(cas_net.twopathconv2.final_layer.parameters(), lr=learning_rate, momentum = 0.9, weight_decay = 5e-10)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)
# Out:
# 332098

# %%
for i in range(num_epoch):
    random.shuffle(data_train_phase2)
    for j in range(step_size):
        training_x1, training_label = create_batch2(batch_size, j)
        x1_train, y_train = Variable(training_x1.cuda(3)), Variable(training_label.cuda(3), requires_grad=False)
        y_pred = cas_net.forward(x1_train)
        y_pred = y_pred.view(-1,5)
        loss = F.cross_entropy(y_pred, y_train)#cross entropy loss

#        l1_crit = nn.L1Loss(size_average = False)#L1 loss
#        reg_loss = 0
#        for param in net.parameters():
#            reg_loss += l1_crit(param)
#        loss+= l1_reg * reg_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #check accuracy
        index=i*step_size+j
        if index % 2000 == 0:
            print ("")
            print (str(index)+' time used %.3f' % (time.clock()-prev_time))
            print ('phase 2: '+str(float(index)/num_times*100)+"% completed")
            print (loss)
            y_val_pred=cas_net.forward(val_x1)
            y_val_pred=y_val_pred.view(-1,5)
            useless, predicted=torch.max(y_val_pred.data, 1)
            correct = (predicted == val_y.cuda(3)).sum()
            print('Validation accuracy:', float(correct)/len(val_y))
    scheduler.step()
    print ("phase2 epoch: " + str(i)+" successfully trained!")
    torch.save(cas_net.state_dict(), "/home/yiqin/phase2_transfer_cas_net.txt")
    print ("phase2 epoch: " + str(i)+" successfully saved!")
# Out:
# 0 time used 134.202
# phase 2: 0.0% completed
# Variable containing:
#  0.5650
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 20 time used 149.885
# phase 2: 0.006022318713150937% completed
# Variable containing:
#  0.6238
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 40 time used 161.487
# phase 2: 0.012044637426301874% completed
# Variable containing:
#  0.5854
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 60 time used 173.065
# phase 2: 0.018066956139452812% completed
# Variable containing:
#  0.5824
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 80 time used 184.617
# phase 2: 0.02408927485260375% completed
# Variable containing:
#  0.5927
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 100 time used 196.224
# phase 2: 0.030111593565754685% completed
# Variable containing:
#  0.6050
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 120 time used 207.863
# phase 2: 0.036133912278905625% completed
# Variable containing:
#  0.5729
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
#
# 140 time used 222.296
# phase 2: 0.04215623099205656% completed
# Variable containing:
#  0.5199
# [torch.cuda.FloatTensor of size 1 (GPU 3)]
#
# Validation accuracy: 0.9187817258883249
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-7d9cfc6b3050> in <module>()
#       2     random.shuffle(data_train_phase2)
#       3     for j in range(200):
# ----> 4         training_x1, training_label = create_batch2(batch_size, j)
#       5         x1_train, y_train = Variable(training_x1.cuda(3)), Variable(training_label.cuda(3), requires_grad=False)
#       6         y_pred = cas_net.forward(x1_train)
#
# <ipython-input-15-769b74d354da> in create_batch2(size, j)
#       7         case1 = case[0:2]
#       8         case2 = case[3:]
# ----> 9         x1 = f[case1][case2][:, x-32:x+32+1, y-32:y+32+1, z]
#      10         train_x1.append(x1)
#      11         train_label.append(l)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1496889914775/work/h5py/_objects.c:2846)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/h5py_1496889914775/work/h5py/_objects.c:2804)()
#
# /home/yiqin/anaconda3/lib/python3.6/site-packages/h5py/_hl/dataset.py in __getitem__(self, args)
#     492         mspace = h5s.create_simple(mshape)
#     493         fspace = selection.id
# --> 494         self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     495
#     496         # Patch up the output for NumPy
#
# KeyboardInterrupt:
